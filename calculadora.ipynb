# %%
print("Calculadora Super Master Racer!!!")

should_exit = False # Flag para controlar a saída do programa

while True:
    # Loop responsável por capturar os números inseridos pelo usuário
    while True:
        try:
            valor_user1 = float(input("Insira o primeiro valor: "))
            valor_user2 = float(input("Insira o segundo valor: "))
            break
        except ValueError:
            print("Insira apenas valores numéricos!")

    #Loop responsável por decidir qual operação matemática realizar
    while True:
        try:
            print('''
            1 - Soma
            2 - Subtração
            3 - Divisão
            4 - Multiplicação
            5 - Escolher números novamente
            0 - Sair
            ''')
            operacao = int(input("Escolha a operação: "))
            total = 0
            if operacao == 1: # Soma
                total = valor_user1 + valor_user2
                print(f"O valor da sua conta é: {total}")
                break
            elif operacao == 2: # Subtração
                total = valor_user1 - valor_user2
                print(f"O valor da sua conta é: {total}")
                break
            elif operacao == 3: # Divisão
                # Tratamento específico para divisão por zero
                if valor_user2 == 0:
                    if valor_user1 == 0:
                        print("Indeterminação matemática! 0/0 não é definido!")
                    else:
                        print("Não é possível dividir por zero!")
                else:
                    total = valor_user1 / valor_user2
                    print(f"O valor da sua conta é: {total}")
                    break
            elif operacao == 4: # Multiplicação
                total = valor_user1 * valor_user2
                print(f"O valor da sua conta é: {total}")
                break
            elif operacao == 5: # Escolher números novamente
                break
            elif operacao == 0: # Sair
                print("Até mais!!")
                should_exit = True # Define a flag para sair do programa
                break # Sai do loop de operações
            else:
                print("Escolha uma operação válida!")
        except ValueError:
            print("Digite uma operação válida!")

    if should_exit: # Verifica a flag após o loop de operações
        break # Sai do loop principal, finalizando o programa
# Out:
# Calculadora Super Master Racer!!!
# Insira o primeiro valor: 10
# Insira o segundo valor: 10
#
#             1 - Soma
#             2 - Subtração
#             3 - Divisão
#             4 - Multiplicação
#             5 - Escolher números novamente
#             0 - Sair
#
# Escolha a operação: 3
# O valor da sua conta é: 1.0
# Insira o primeiro valor: 0
# Insira o segundo valor: 5
#
#             1 - Soma
#             2 - Subtração
#             3 - Divisão
#             4 - Multiplicação
#             5 - Escolher números novamente
#             0 - Sair
#
# Escolha a operação: 3
# O valor da sua conta é: 0.0
# Insira o primeiro valor: 10
# Insira o segundo valor: 30
#
#             1 - Soma
#             2 - Subtração
#             3 - Divisão
#             4 - Multiplicação
#             5 - Escolher números novamente
#             0 - Sair
#
# Escolha a operação: 0
# Até mais!!
